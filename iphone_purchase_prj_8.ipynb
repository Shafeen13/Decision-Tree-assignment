# %%
import pandas as pd
import numpy as np
import math as m
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier  
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
import warnings
warnings.filterwarnings("ignore")

# %%
# reading the data file--
data=pd.read_csv("C:/Users/PC PC/Desktop/DS Assignment/Ml projects/Decision Tree  - Assignment -4/iphone_purchase_records.csv")

# %%
# calling the function--
print(data.head(2))
# Out:
#   Gender  Age  Salary  Purchase Iphone
# 0   Male   19   19000                0
# 1   Male   35   20000                0

# %%
#processsing the data

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Salary', 'Purchase Iphone'], dtype='object')

# %%
data.shape
# Out:
# (400, 4)

# %%
data.isnull().sum()
# Out:
# Gender             0
# Age                0
# Salary             0
# Purchase Iphone    0
# dtype: int64

# %%
data.dtypes
# Out:
# Gender             object
# Age                 int64
# Salary              int64
# Purchase Iphone     int64
# dtype: object

# %%
data.drop('Gender', axis=1, inplace=True)

# %%
#EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   Salary           400 non-null    int64
#  2   Purchase Iphone  400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
data.describe()
# Out:
#               Age         Salary  Purchase Iphone
# count  400.000000     400.000000       400.000000
# mean    37.655000   69742.500000         0.357500
# std     10.482877   34096.960282         0.479864
# min     18.000000   15000.000000         0.000000
# 25%     29.750000   43000.000000         0.000000
# 50%     37.000000   70000.000000         0.000000
# 75%     46.000000   88000.000000         1.000000
# max     60.000000  150000.000000         1.000000

# %%
# checking the outliers--
sns.boxplot(data)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=data, x='Salary', y='Age')
plt.title('Salary vs Age')
# Out:
# Text(0.5, 1.0, 'Salary vs Age')

# %%
sns.scatterplot(data=data, x='Purchase Iphone', y='Salary')
plt.title('Purchase Iphone vs Salary')
# Out:
# Text(0.5, 1.0, 'Purchase Iphone vs Salary')

# %%
sns.heatmap(data.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Splitting the data into training and testing datasets

# %%
X=data.drop('Purchase Iphone', axis=1).values
y=data['Purchase Iphone'].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=18, stratify=Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=18, stratify=Y)
#
# NameError: name 'Y' is not defined

# %% [markdown]
# Model Predictions

# %%
model = DecisionTreeClassifier()
model_train = model.fit(X_train,y_train)
print("Model training is completed")
pred = model_train.predict(X_test)

# %%
pred

# %%
accuracy_score(y_test,pred)

# %%
con=confusion_matrix(y_test,pred)
con

# %%
model_train.classes_

# %%
ConfusionMatrixDisplay(con,display_labels=model_train.classes_,).plot()
